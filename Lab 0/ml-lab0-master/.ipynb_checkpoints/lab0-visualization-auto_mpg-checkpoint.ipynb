# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_fwf("auto-mpg.data", na_values='?')

# %%
data.columns=['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'car name']

# %%
data.set_index('car name')
# Out:
#                        mpg  cylinders  displacement  horsepower  weight  \
# car name
# "buick skylark 320"   15.0          8         350.0       165.0  3693.0
# "plymouth satellite"  18.0          8         318.0       150.0  3436.0
# "amc rebel sst"       16.0          8         304.0       150.0  3433.0
# "ford torino"         17.0          8         302.0       140.0  3449.0
# "ford galaxie 500"    15.0          8         429.0       198.0  4341.0
# ...                    ...        ...           ...         ...     ...
# "ford mustang gl"     27.0          4         140.0        86.0  2790.0
# "vw pickup"           44.0          4          97.0        52.0  2130.0
# "dodge rampage"       32.0          4         135.0        84.0  2295.0
# "ford ranger"         28.0          4         120.0        79.0  2625.0
# "chevy s-10"          31.0          4         119.0        82.0  2720.0
#
#                       acceleration  model year  origin
# car name
# "buick skylark 320"           11.5          70       1
# "plymouth satellite"          11.0          70       1
# "amc rebel sst"               12.0          70       1
# "ford torino"                 10.5          70       1
# "ford galaxie 500"            10.0          70       1
# ...                            ...         ...     ...
# "ford mustang gl"             15.6          82       1
# "vw pickup"                   24.6          82       2
# "dodge rampage"               11.6          82       1
# "ford ranger"                 18.6          82       1
# "chevy s-10"                  19.4          82       1
#
# [397 rows x 8 columns]

# %%
print(data.head(5))
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  15.0          8         350.0       165.0  3693.0          11.5
# 1  18.0          8         318.0       150.0  3436.0          11.0
# 2  16.0          8         304.0       150.0  3433.0          12.0
# 3  17.0          8         302.0       140.0  3449.0          10.5
# 4  15.0          8         429.0       198.0  4341.0          10.0
#
#    model year  origin              car name
# 0          70       1   "buick skylark 320"
# 1          70       1  "plymouth satellite"
# 2          70       1       "amc rebel sst"
# 3          70       1         "ford torino"
# 4          70       1    "ford galaxie 500"

# %%
data.plot()
# Out:
# <AxesSubplot: >

# %%
data['mpg'].plot.hist();

# %%
data['horsepower'].plot.hist();

# %%
data.origin.value_counts()
# Out:
# 1    248
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
axs = data.hist(column='mpg', by='origin')

# %%
axs = data.hist(column='mpg', by='origin')
# axs[1].set(title='female', ylim=[0, 45])
# axs[2].set(title='male', ylim=[0, 45])
# axs[3].set(title='water', ylim=[0,45]);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 axs = data.hist(column='mpg', by='origin')
# ----> 2 axs[1].set(title='female', ylim=[0, 45])
#       3 axs[2].set(title='male', ylim=[0, 45])
#       4 axs[3].set(title='water', ylim=[0,45])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set'

# %%
data.plot.scatter('mpg', 'horsepower', c='origin', colormap='winter');

# %%
fig, ax = plt.subplots()
data.plot.scatter('mpg', 'horsepower', c='origin', colormap='viridis', ax=ax);

# %%
colors = {1: 'tab:blue', 2: 'tab:orange', 3: 'tab:brown'}
fig, ax = plt.subplots()
for key, group in data.groupby(by='origin'):
    group.plot.scatter('mpg', 'horsepower', c=colors[key], label=key, ax=ax);

# %%
import seaborn as sns

# %%
sns.displot(x='horsepower', col='origin', data=data);

# %%
sns.displot(x='horsepower', hue='origin', data=data);

# %%
sns.displot(x='horsepower', hue='origin', data=data, multiple='stack');

# %%
sns.boxplot(x='mpg', y='origin', data=data);

# %%
data['origin_str'] = data['origin'].replace([1,2,3], ['one', 'two', 'three'])
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    15.0          8         350.0       165.0  3693.0          11.5
# 1    18.0          8         318.0       150.0  3436.0          11.0
# 2    16.0          8         304.0       150.0  3433.0          12.0
# 3    17.0          8         302.0       140.0  3449.0          10.5
# 4    15.0          8         429.0       198.0  4341.0          10.0
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         140.0        86.0  2790.0          15.6
# 393  44.0          4          97.0        52.0  2130.0          24.6
# 394  32.0          4         135.0        84.0  2295.0          11.6
# 395  28.0          4         120.0        79.0  2625.0          18.6
# 396  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year origin              car name origin_str
# 0            70    one   "buick skylark 320"        one
# 1            70    one  "plymouth satellite"        one
# 2            70    one       "amc rebel sst"        one
# 3            70    one         "ford torino"        one
# 4            70    one    "ford galaxie 500"        one
# ..          ...    ...                   ...        ...
# 392          82    one     "ford mustang gl"        one
# 393          82    two           "vw pickup"        two
# 394          82    one       "dodge rampage"        one
# 395          82    one         "ford ranger"        one
# 396          82    one          "chevy s-10"        one
#
# [397 rows x 10 columns]

# %%
ax = sns.scatterplot(x='horsepower', y='mpg', data=data, hue='origin_str')

# %%
ax = sns.lmplot(x='horsepower', y='mpg', data=data, hue='origin_str')

# %%
sns.pairplot(data, vars=['horsepower', 'mpg', 'model year', 'acceleration'], hue='origin_str');

# %%
g = sns.heatmap(data[['mpg', 'horsepower', 'model year', 'acceleration']].corr(method='spearman'), 
            annot=True)

# %%
conda env list
# Out:
# # conda environments:
# #
# base                     /Users/olusolaakinbode/opt/anaconda3
# ensf592                  /Users/olusolaakinbode/opt/anaconda3/envs/ensf592
# ensf611               *  /Users/olusolaakinbode/opt/anaconda3/envs/ensf611
#
#
# Note: you may need to restart the kernel to use updated packages.
